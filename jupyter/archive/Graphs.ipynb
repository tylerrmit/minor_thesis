# %%
import os
import pandas as pd

import matplotlib.pyplot as plt

# %%
df = pd.read_csv(os.path.join(os.pardir, 'V1_training.csv'))
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-d06f9eb31903> in <module>
# ----> 1 df = pd.read_csv(os.path.join(os.pardir, 'V1_training.csv'))
#       2 df.head(3)
#
# D:\ProgramData\Anaconda3\envs\gpuEnv\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df2 = pd.read_csv(os.path.join('os.pardir', 'V2_training.csv'))
df2.head(3)
# Out:
#          Model  Steps  train_TotalLoss  test_mAP  Train_FP  Train_FN  Test_FP  \
# 0  Faster RCNN    100           0.1172  0.000000       0.0     457.0      0.0
# 1  Faster RCNN   2000           0.0852  0.293945       1.0       8.0      3.0
# 2  Faster RCNN   4000           0.0985  0.428875       0.0       8.0      1.0
#
#    Test_FN
# 0    136.0
# 1      9.0
# 2      2.0

# %%
os.chdir(os.pardir)

# %%
df.set_index('Steps', inplace=True)
df.head(3)
# Out:
#            Model  train_TotalLoss  test_mAP  Train_FP  Train_FN  Test_FP  \
# Steps
# 100    CenterNet           2.8379  0.000000       NaN       NaN      NaN
# 500    CenterNet           0.7392  0.000000       NaN       NaN      NaN
# 1000   CenterNet           0.6276  0.635953       NaN       NaN      NaN
#
#        Test_FN
# Steps
# 100        NaN
# 500        NaN
# 1000       NaN

# %%
df.groupby("Model")["test_mAP"].plot(
    legend=True,
    xlabel="Training Steps",
    ylabel="Evaluation Mean Average Precision (mAP)",
    title = "Detection Box Mean Average Precision vs. Test Dataset during training\n\nGSV Models"
)
plt.savefig("fig_gsv_map.png")
plt.show()

# %%
df.groupby("Model")["train_TotalLoss"].plot(
    legend=True,
    xlabel="Training Steps",
    ylabel="Training Total Loss",
    title="Total Loss vs. Training Dataset during training\n\nGSV Models"
)
plt.savefig("fig_gsv_loss.png")
plt.show()

# %%
df2.set_index('Steps', inplace=True)
df2.head(3)
# Out:
#              Model  train_TotalLoss  test_mAP  Train_FP  Train_FN  Test_FP  \
# Steps
# 100    Faster RCNN           0.1172  0.000000       0.0     457.0      0.0
# 2000   Faster RCNN           0.0852  0.293945       1.0       8.0      3.0
# 4000   Faster RCNN           0.0985  0.428875       0.0       8.0      1.0
#
#        Test_FN
# Steps
# 100      136.0
# 2000       9.0
# 4000       2.0

# %%
df2.groupby("Model")["test_mAP"].plot(
    legend=True,
    xlabel="Training Steps",
    ylabel="Evaluation Mean Average Precision (mAP)",
    title = "Detection Box Mean Average Precision vs. Test Dataset during training\n\nDashcam Models"
)
plt.savefig("fig_dash_map.png")
plt.show()

# %%
df2.groupby("Model")["train_TotalLoss"].plot(
    legend=True,
    xlabel="Training Steps",
    ylabel="Training Total Loss",
    title="Total Loss vs. Training Dataset during training\n\nDashcam Models"
)
plt.savefig("fig_dash_loss.png")
plt.show()

# %%
df = pd.read_csv(os.path.join('..', '..', 'stats.csv'))
df.set_index('Steps', inplace=True)
df.head(3)
# Out:
#              Model  Total Loss       mAP  Hits 55  False Positive 55  \
# Steps
# 2000   Faster RCNN      0.0403  0.618293      211                 54
# 10000  Faster RCNN      0.0072  0.681168      228                 74
# 20000  Faster RCNN      0.0066  0.686988      205                 51
#
#        Precision 55  Hits 60  False Positive 60  Precision 60
# Steps
# 2000       0.744076      208                 54      0.740385
# 10000      0.675439      226                 74      0.672566
# 20000      0.751220      203                 51      0.748768

# %%
df.groupby("Model")["Precision 60"].plot(
    legend=True,
    xlabel="Training Steps",
    ylabel="Precision",
    title = "Detection Precision vs. Test Dataset during training\n\nMount Eliza Survey Area, GSV Models, 60% Confidence Threshold"
)
plt.savefig("fig_gsv_precision.png")
plt.show()

# %%
df.groupby("Model")["False Positive 60"].plot(
    legend=True,
    xlabel="Training Steps",
    ylabel="False Positives",
    title = "Detection Precision vs. Test Dataset during training\n\nMount Eliza Survey Area, GSV Models, 60% Confidence Threshold"
)
plt.savefig("fig_gsv_false_positives.png")
plt.show()
